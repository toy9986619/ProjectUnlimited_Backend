# %%
import pyspark
from pyspark.sql import SparkSession
sc = pyspark.SparkContext('local[*]')
spark = SparkSession.builder.appName("calculateSaleRate").getOrCreate()

# %%
global Path
if sc.master[0:5] == "local":
    Path = "file:/home/jovyan/work/csvData/CSV/"
else:
    Path = "hdfs:/user/zeppelin/csvData/CSV/"

# %%
from operator import add
from pyspark.sql.types import StructType, StructField, IntegerType, StringType, DateType, FloatType
import time
import math
import datetime
from pyspark.sql.functions import monotonically_increasing_id, array_contains
import re

# %%
productSchema = StructType([
    StructField("item_id", IntegerType(), True),
    StructField("shop_id", IntegerType(), True),
    StructField("shop_name", StringType(), True),
    StructField("category_name", StringType(), True),
    StructField("name", StringType(), True),
    StructField("hashtag", StringType(), True),
    StructField("trade_in", FloatType(), True),
    StructField("price", IntegerType(), True),
    StructField("sale", IntegerType(), True),
    StructField("score_avg", FloatType(), True),
    StructField("score_num", IntegerType(), True),
    StructField("stock", IntegerType(), True),
    StructField("need_day", IntegerType(), True),
    StructField("url", StringType(), True),
    StructField("content", StringType(), True),
    StructField("update_time", DateType(), True)])

#productDf = spark.read.csv(Path+"2018-04-01 shopee_product.csv",header=False,schema=productSchema,quote='')

# %%
def makeRDD(line):
    line = line.split(",")
    
    if line[0] != "item_id":
        for i in range(len(line)):
            if line[i]=="":
                line[i]=0
                
        return [int(line[0]), int(line[1]), line[2], line[3], line[4], line[5], float(line[6]), int(line[7]), int(line[8]), float(line[9]), int(line[10]), int(line[11]), int(line[12]), line[13], line[14]]
    
    else:
        return line

# %%
productRDD = sc.parallelize([])

# %%
for i in range(1,12):
    if i <10:
        date = "2018-04-0"+str(i)
        filename = Path + date +" shopee_product.csv"
    elif 10 <= i and i < 31:
        date = "2018-04-"+str(i)
        filename = Path + date +" shopee_product.csv"
    date = datetime.datetime.strptime(date, '%Y-%m-%d')
    readRDD = sc.textFile(filename).map(makeRDD).map(lambda line: tuple(line)+(date,))
    productRDD = productRDD.union(readRDD)

# %%
productRDD = productRDD.filter(lambda line: line[0]!="item_id")
productRDD.take(3)
# Out:
# [(290925436,
#   2022130,
#   'yiting1211',
#   'iPhone保護殼',
#   '可超取iphone6__iphone6S_47吋_迪士尼_米奇放大鏡_軟殼_手機殼',
#   0,
#   9.0,
#   100,
#   0,
#   0.0,
#   0,
#   0,
#   0,
#   'https://shopee.tw/%E3%80%90%E5%8F%AF%E8%B6%85%E5%8F%96%E3%80%91iphone6-iphone6S-(4.7%E5%90%8B)-%E8%BF%AA%E5%A3%AB%E5%B0%BC-%E7%B1%B3%E5%A5%87%E6%94%BE%E5%A4%A7%E9%8F%A1-%E8%BB%9F%E6%AE%BC-%E6%89%8B%E6%A9%9F%E6%AE%BC-i.2022130.290925436',
#   '可超取iphone6__iphone6S_47吋_迪士尼_米奇放大鏡_軟殼_手機殼售價150元',
#   datetime.datetime(2018, 4, 1, 0, 0)),
#  (1008696376,
#   59323996,
#   'kaixina',
#   'Android保護殼',
#   '潮流女神欧美爆款日韩名媛潮英伦学院风摇滚庞克仿旧百搭厚底坡跟涼鞋夏2017韓版新款羅馬鞋超高跟防水臺鏤空甜美露趾女鞋',
#   '#女鞋#歐美#羅馬風格#簡約#小白鞋#英倫#韓版#休閒鞋#粗跟#綁帶#高跟鞋#復古#運動鞋#洞洞鞋#平底鞋#帆布鞋#拖鞋#涼鞋',
#   4.3,
#   800,
#   0,
#   0.0,
#   0,
#   120,
#   -1,
#   'https://shopee.tw/%E6%BD%AE%E6%B5%81%E5%A5%B3%E7%A5%9E%E6%AC%A7%E7%BE%8E%E7%88%86%E6%AC%BE%E6%97%A5%E9%9F%A9%E5%90%8D%E5%AA%9B%E6%BD%AE%E8%8B%B1%E4%BC%A6%E5%AD%A6%E9%99%A2%E9%A3%8E%E6%91%87%E6%BB%9A%E5%BA%9E%E5%85%8B%E4%BB%BF%E6%97%A7%E7%99%BE%E6%90%AD%E5%8E%9A%E5%BA%95%E5%9D%A1%E8%B7%9F%E6%B6%BC%E9%9E%8B%E5%A4%8F2017%E9%9F%93%E7%89%88%E6%96%B0%E6%AC%BE%E7%BE%85%E9%A6%AC%E9%9E%8B%E8%B6%85%E9%AB%98%E8%B7%9F%E9%98%B2%E6%B0%B4%E8%87%BA%E9%8F%A4%E7%A9%BA%E7%94%9C%E7%BE%8E%E9%9C%B2%E8%B6%BE%E5%A5%B3%E9%9E%8B-i.59323996.1008696376',
#   '_',
#   datetime.datetime(2018, 4, 1, 0, 0)),
#  (244935440,
#   7338131,
#   'vawa31',
#   'iPhone充電傳輸',
#   '微型商店Jetart_Lightning_USB_強化傳輸線15m_IPHONE_充電線_CAA220',
#   0,
#   4.3,
#   499,
#   0,
#   0.0,
#   0,
#   99,
#   -1,
#   'https://shopee.tw/%E3%80%90%E5%BE%AE%E5%9E%8B%E5%95%86%E5%BA%97%E3%80%91Jetart-Lightning-USB-%E5%BC%B7%E5%8C%96%E5%82%B3%E8%BC%B8%E7%B7%9A1.5m-IPHONE-%E5%85%85%E9%9B%BB%E7%B7%9A-CAA220-i.7338131.244935440',
#   '商品說明_Jetart_Lightning_to_USB強化傳輸線_APPLE認證授權型號CAA220捷藝科技成立於1989年以全系列電腦散熱器及電腦週邊產品為營運重心於2001年通過ISO9001之品質管理認證並於2005年建立_JETART_自有品牌行銷台灣及全球通路市場為貫徹品質服務創新的核心精神我們以台灣為主要生產基地從研發製造到全球行銷一貫作業秉持不斷創新之研發精神我們至今已擁有數百項產品除了取得超過百項新型及發明專利外並已通過眾多國際品牌大廠之代工認證我們重視每一個產品的設計環節製造技術及品質管控使得每一個從捷藝科技出廠的產品都能以最佳品質滿足客戶的需求產品特色小型插座模組設計傳輸充電兩用功能Lightning_可雙面插接支援iOS_8以上版本強化耐拉拔超優質鋁合金外殼_商品規格_產品重量22_g長度15m顏色鐵灰色__黑線外殼材質鋁合金國際條碼4711182335731PS_下標時請註明顏色若無則隨機出貨資料來源Jetart商品圖檔顏色因電腦螢幕設定差異會略有不同以實際商品顏色為準_以上規格資料若有任何錯誤以原廠所公佈資料為準__微型商店_c_All_rights_reserved',
#   datetime.datetime(2018, 4, 1, 0, 0))]

# %%
productDF = spark.createDataFrame(productRDD, productSchema)
productDF.show(3)
# Out:
# +----------+--------+----------+-------------+--------------------+--------------------+--------+-----+----+---------+---------+-----+--------+--------------------+--------------------+-----------+
# |   item_id| shop_id| shop_name|category_name|                name|             hashtag|trade_in|price|sale|score_avg|score_num|stock|need_day|                 url|             content|update_time|
# +----------+--------+----------+-------------+--------------------+--------------------+--------+-----+----+---------+---------+-----+--------+--------------------+--------------------+-----------+
# | 290925436| 2022130|yiting1211|    iPhone保護殼|可超取iphone6__iphon...|                   0|     9.0|  100|   0|      0.0|        0|    0|       0|https://shopee.tw...|可超取iphone6__iphon...| 2018-04-01|
# |1008696376|59323996|   kaixina|   Android保護殼|潮流女神欧美爆款日韩名媛潮英伦学院...|#女鞋#歐美#羅馬風格#簡約#小白...|     4.3|  800|   0|      0.0|        0|  120|      -1|https://shopee.tw...|                   _| 2018-04-01|
# | 244935440| 7338131|    vawa31|   iPhone充電傳輸|微型商店Jetart_Lightn...|                   0|     4.3|  499|   0|      0.0|        0|   99|      -1|https://shopee.tw...|商品說明_Jetart_Light...| 2018-04-01|
# +----------+--------+----------+-------------+--------------------+--------------------+--------+-----+----+---------+---------+-----+--------+--------------------+--------------------+-----------+
# only showing top 3 rows

# %%
productDF.filter("stock = 0").rdd.take(5)
# Out:
# [Row(item_id=290925436, shop_id=2022130, shop_name='yiting1211', category_name='iPhone保護殼', name='可超取iphone6__iphone6S_47吋_迪士尼_米奇放大鏡_軟殼_手機殼', hashtag='0', trade_in=9.0, price=100, sale=0, score_avg=0.0, score_num=0, stock=0, need_day=0, url='https://shopee.tw/%E3%80%90%E5%8F%AF%E8%B6%85%E5%8F%96%E3%80%91iphone6-iphone6S-(4.7%E5%90%8B)-%E8%BF%AA%E5%A3%AB%E5%B0%BC-%E7%B1%B3%E5%A5%87%E6%94%BE%E5%A4%A7%E9%8F%A1-%E8%BB%9F%E6%AE%BC-%E6%89%8B%E6%A9%9F%E6%AE%BC-i.2022130.290925436', content='可超取iphone6__iphone6S_47吋_迪士尼_米奇放大鏡_軟殼_手機殼售價150元', update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=185992271, shop_id=15709005, shop_name='lovephonefashion', category_name='Apple空機', name='愛瘋時尚iphone5_16g_銀色', hashtag='#iphone#iphone5', trade_in=10.0, price=4000, sale=0, score_avg=0.0, score_num=0, stock=0, need_day=-1, url='https://shopee.tw/%E3%80%90%E6%84%9B%E7%98%8B%E6%99%82%E5%B0%9A%E3%80%91iphone5-16g-%E9%8A%80%E8%89%B2-i.15709005.185992271', content='_', update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=735413824, shop_id=13745281, shop_name='spirit0415', category_name='耳機喇叭', name='jabra_move_wireless無線藍牙耳罩式耳機', hashtag='0', trade_in=9.800000190734863, price=2300, sale=0, score_avg=0.0, score_num=0, stock=0, need_day=-1, url='https://shopee.tw/jabra-move-wireless%E7%84%A1%E7%B7%9A%E8%97%8D%E7%89%99%E8%80%B3%E7%BD%A9%E5%BC%8F%E8%80%B3%E6%A9%9F-i.13745281.735413824', content='九成新盒裝完整保內', update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=469012152, shop_id=13161531, shop_name='jjj0963000003', category_name='Android空機', name='JH_手機快修_HTC_820_16G_全功能正常_保固3個月', hashtag='0', trade_in=8.0, price=2500, sale=0, score_avg=5.0, score_num=1, stock=0, need_day=0, url='https://shopee.tw/JH-%E6%89%8B%E6%A9%9F%E5%BF%AB%E4%BF%AE-HTC-820-16G-%E5%85%A8%E5%8A%9F%E8%83%BD%E6%AD%A3%E5%B8%B8-%E4%BF%9D%E5%9B%BA3%E5%80%8B%E6%9C%88-i.13161531.469012152', content='JH_手機快修_HTC_820_16G_全功能正常_保固3個月', update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=455577904, shop_id=27113929, shop_name='mp987555739', category_name='Android空機', name='ET手機倉庫館9成新_HTC_One_M9_銀_32G_八核心_52吋_2000萬_4G_現貨_M9pw', hashtag='#HTC#現貨', trade_in=10.0, price=3890, sale=0, score_avg=0.0, score_num=0, stock=0, need_day=0, url='https://shopee.tw/%E2%98%86ET%E6%89%8B%E6%A9%9F%E5%80%89%E5%BA%AB%EF%BC%95%E9%A4%A8%E2%98%869%E6%88%90%E6%96%B0%EF%BC%81-HTC-One-M9-%E9%8A%80-32G-%E5%85%AB%E6%A0%B8%E5%BF%83-5.2%E5%90%8B-2000%E8%90%AC-4G-%E7%8F%BE%E8%B2%A8-M9pw-i.27113929.455577904', content='簡配原廠電池原廠旅充原廠傳輸線原廠耳機退卡針發票狀況約9成新_邊框細刮商品為實拍圖細刮拍不出來備註銀色32GB上市日期201505保固賣方保固三個月代理商HTC公司貨通訊系統GSM850900180019003G4G適用4G中華電信_台灣大哥大_遠傳電信_Gt_智慧生活_台灣之星_52_吋_2K_Quad_HD_觸控螢幕2560__1440pixels_螢幕解析度_採用_Android_50_Lollipop_作業系統__HTC_Sense_7_操作介面_內建_64_位元聯發科_MediaTek_MT6795_22GHz_八核心處理器_2000_萬畫素_BSI_主相機__Duo_Camera_景深鏡頭F20_光圈278mm_廣角4K_UHD_錄影_408_萬畫素_UltraPixel_前置鏡頭F20_光圈268mm_廣角1080P_Full_HD_錄影_支援_4G_LTE_網路WiFi_80211_abgnac24__5_GHz_支援指紋辨識DLNAHDMI_MHL_20NFC藍牙_41紅外線遙控GPS__GLONASS_內建_3GB_RAM__32GB_ROM_儲存空間_支援_microSD_記憶卡擴充最高至_2TB_記憶體容量', update_time=datetime.date(2018, 4, 1))]

# %%
productDF.count()
# Out:
# 169992

# %%
dataRDD = productDF.select("item_id", "category_name", "name", "price", "sale", "score_avg", "score_num", "stock", "update_time")

# %%
dataRDD.take(5)
# Out:
# [Row(item_id=290925436, category_name='iPhone保護殼', name='可超取iphone6__iphone6S_47吋_迪士尼_米奇放大鏡_軟殼_手機殼', price=100, sale=0, score_avg=0.0, score_num=0, stock=0, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=1008696376, category_name='Android保護殼', name='潮流女神欧美爆款日韩名媛潮英伦学院风摇滚庞克仿旧百搭厚底坡跟涼鞋夏2017韓版新款羅馬鞋超高跟防水臺鏤空甜美露趾女鞋', price=800, sale=0, score_avg=0.0, score_num=0, stock=120, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=244935440, category_name='iPhone充電傳輸', name='微型商店Jetart_Lightning_USB_強化傳輸線15m_IPHONE_充電線_CAA220', price=499, sale=0, score_avg=0.0, score_num=0, stock=99, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=78503770, category_name='平板電腦', name='愛買舖全新_平板_SuperPad_A1967_97吋_3G通話上網_8核架構_16G_老人機__通話平板', price=3990, sale=0, score_avg=0.0, score_num=0, stock=5, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=627940626, category_name='Android保護殼', name='全民3C_日本東映授權正版_航海王_ZenFone_4_ZE554KL_彩繪磁力皮套封鎖羅_手機皮套_保護套', price=399, sale=0, score_avg=0.0, score_num=0, stock=20, update_time=datetime.date(2018, 4, 1))]

# %% [markdown]
# # 查看資料筆數分佈情況

# %%
testCountRDD = productDF.select("item_id").rdd.map(lambda x: (x,1)).reduceByKey(add)
testCountRDD.count()
# Out:
# 70408

# %%
testCountRDD = testCountRDD.map(lambda x:(x[1], 1)).reduceByKey(add)
testCountRDD.count()
# Out:
# 9

# %%
testCountRDD.collect()
# Out:
# [(1, 25327),
#  (2, 18553),
#  (3, 11523),
#  (4, 3751),
#  (5, 10199),
#  (6, 547),
#  (7, 370),
#  (8, 123),
#  (9, 15)]

# %%
productDF.select("item_id").distinct().count()
# Out:
# 70408

# %% [markdown]
# # 建立測試用資料

# %% [markdown]
# ### 依據item_id 將資料轉換形式

# %%
testDataRDD = dataRDD.rdd.map(lambda x: (x[0], list(x[1:]))).groupByKey().map(lambda x: (x[0], list(x[1])))
testDataRDD.take(3)
# Out:
# [(469012152,
#   [['Android空機',
#     'JH_手機快修_HTC_820_16G_全功能正常_保固3個月',
#     2500,
#     0,
#     5.0,
#     1,
#     0,
#     datetime.date(2018, 4, 1)]]),
#  (545299512,
#   [['手機周邊配件',
#     '雅客方舟Nike_證件帶_手機掛環_現貨',
#     229,
#     0,
#     0.0,
#     0,
#     150,
#     datetime.date(2018, 4, 1)]]),
#  (862832544, [['其他', '手機掛繩_白色', 15, 0, 0.0, 0, 1, datetime.date(2018, 4, 1)]])]

# %% [markdown]
# ### 取得資料筆數>5的資料群

# %%
count5RDD = testDataRDD.filter(lambda x: len(x[1])>=5)
count5RDD.count()
# Out:
# 11254

# %% [markdown]
# ### 依據評價數計算銷售頻率

# %%
def countSaleRateByScore(line):
    # (id, list)
    score_count = line[1][-1][5] - line[1][0][5]
    date = (line[1][-1][-1] - line[1][0][-1]).days
    
    saleRate = score_count / date * 1.0
    
    return (line[0], score_count, date, saleRate)

# %%
count5SaleRateRDD = count5RDD.map(countSaleRateByScore)
count5SaleRateRDD.count()
# Out:
# 11254

# %%
count5SaleRateRDD.take(3)
# Out:
# [(201666072, 0, 9, 0.0), (1001361696, 0, 10, 0.0), (44400816, 0, 9, 0.0)]

# %%
count5SaleRateRDD.filter(lambda x: x[-1]>0).count()
# Out:
# 214

# %% [markdown]
# ### 依據庫存計算銷售頻率

# %%
def countSaleRateByStock(line):
    #(id, list)
    baseStock = line[1][0][6]
    stockCount = 0
    date = 0
    stockDelta = 0
    category = line[1][0][0]
    name = line[1][0][1]
    saleDelta = 0
    
    for i in range(len(line[1])-1):
        saleDelta = abs(line[1][i+1][3] - line[1][i][3]) #月銷量變化
        if line[1][i][6] >= line[1][i+1][6]:
            stockDelta = (line[1][i][6] - line[1][i+1][6])
            baseStock = line[1][i+1][6]
            
            if stockDelta >= saleDelta: #庫存變化 > 月銷量變化 => 下調庫存量
                stockDelta=0
            
            stockCount += stockDelta
            date += (line[1][i+1][-1] - line[1][i][-1]).days
        
        elif line[1][i][6] < line[1][i+1][6]:
            baseStock = line[1][i+1][6]
            filterStock = baseStock
            
        elif baseStock == 0 :
            continue
        
    
    #date = (line[1][-1][-1] - line[1][0][-1]).days
    if date > 0 :
        saleRate = stockDelta / date * 1.0
    else:
        saleRate = 0.0
    
    return (line[0], category, name, stockCount, date, saleRate)

# %%
count5StockSaleRateRDD = count5RDD.map(countSaleRateByStock)
count5StockSaleRateRDD.count()
# Out:
# 11254

# %%
count5StockSaleRateRDD.take(3)
# Out:
# [(201666072, 0, 9, 0.0), (1001361696, 0, 10, 0.0), (44400816, 0, 9, 0.0)]

# %%
count5StockSaleRateRDD.filter(lambda x: x[-1]>0).take(10)
# Out:
# [(8459184, 1, 4, 0.25),
#  (8536896, 25, 4, 1.5),
#  (896398800, 1, 4, 0.25),
#  (251176728, 1, 3, 0.3333333333333333),
#  (60200712, 1, 4, 0.25),
#  (14111545, 8, 7, 1.0),
#  (19331497, 5, 4, 0.5),
#  (114088945, 4, 5, 0.2),
#  (42291049, 1, 4, 0.25),
#  (465216985, 2, 3, 0.3333333333333333)]

# %%
count5StockSaleRateRDD.takeOrdered(10, key=lambda x: -x[-1])
# Out:
# [(4959332, 93, 4, 7.0),
#  (525232698, 26, 4, 2.75),
#  (68359654, 20, 4, 2.75),
#  (191969759, 29, 4, 2.75),
#  (457334233, 15, 4, 2.5),
#  (5595311, 41, 4, 2.5),
#  (192279461, 12, 4, 2.25),
#  (342120467, 19, 8, 2.125),
#  (19648171, 20, 4, 1.75),
#  (8536896, 25, 4, 1.5)]

# %%
productDF.select("item_id", "sale", "score_num", "stock", "update_time").filter('item_id = 4959332').rdd.collect()
# Out:
# [Row(item_id=4959332, sale=856, score_num=4017, stock=4378, update_time=datetime.date(2018, 4, 6)),
#  Row(item_id=4959332, sale=827, score_num=4032, stock=4359, update_time=datetime.date(2018, 4, 7)),
#  Row(item_id=4959332, sale=802, score_num=4051, stock=4341, update_time=datetime.date(2018, 4, 8)),
#  Row(item_id=4959332, sale=781, score_num=4059, stock=4313, update_time=datetime.date(2018, 4, 9)),
#  Row(item_id=4959332, sale=782, score_num=4081, stock=4285, update_time=datetime.date(2018, 4, 10))]

# %%
productDF.select("item_id", "sale", "score_num", "stock", "update_time").filter('sale >= 10').rdd.collect()
# Out:
# [Row(item_id=864699726, sale=17, score_num=14, stock=10, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=8388865, sale=25, score_num=70, stock=5948, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=557538607, sale=29, score_num=167, stock=1290, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=65025241, sale=20, score_num=75, stock=9908, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=180192578, sale=20, score_num=205, stock=1577, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=8012139, sale=12, score_num=35, stock=44, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=505033631, sale=16, score_num=37, stock=1317, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=380970962, sale=42, score_num=90, stock=824, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=276866438, sale=134, score_num=58, stock=3547, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=177921273, sale=48, score_num=170, stock=183, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=820779787, sale=17, score_num=17, stock=2964, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=867696272, sale=25, score_num=13, stock=112, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=852524434, sale=10, score_num=8, stock=983, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=856851245, sale=17, score_num=23, stock=256, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=1009257775, sale=10, score_num=0, stock=1, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=652279900, sale=15, score_num=39, stock=1, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=235643149, sale=76, score_num=278, stock=4781, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=571005005, sale=35, score_num=55, stock=196, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=977793140, sale=10, score_num=2, stock=16990, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=384801279, sale=17, score_num=38, stock=815, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=27642240, sale=15, score_num=19, stock=26, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=172405182, sale=15, score_num=216, stock=3781, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=285673031, sale=576, score_num=265, stock=490, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=21145235, sale=10, score_num=74, stock=22, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=240552893, sale=19, score_num=71, stock=81, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=528906027, sale=27, score_num=88, stock=1686, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=14696239, sale=14, score_num=131, stock=268, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=512962372, sale=16, score_num=41, stock=951, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=457573650, sale=62, score_num=377, stock=60, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=986080162, sale=69, score_num=3, stock=531, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=724382133, sale=51, score_num=58, stock=23, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=917389265, sale=12, score_num=7, stock=11, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=938883175, sale=18, score_num=14, stock=461, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=498181341, sale=26, score_num=29, stock=245, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=18269565, sale=22, score_num=51, stock=266611, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=70547876, sale=18, score_num=6, stock=64, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=66126120, sale=13, score_num=144, stock=11909, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=509173739, sale=17, score_num=84, stock=83, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=186573898, sale=64, score_num=129, stock=6826, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=5962349, sale=165, score_num=557, stock=76, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=876861074, sale=11, score_num=9, stock=502, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=314407113, sale=19, score_num=72, stock=262, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=321546856, sale=31, score_num=26, stock=10, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=13444341, sale=11, score_num=243, stock=503, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=23307646, sale=38, score_num=242, stock=162, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=842277616, sale=11, score_num=19, stock=1, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=189399, sale=10, score_num=229, stock=136766, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=639511947, sale=108, score_num=296, stock=2590, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=954857363, sale=12, score_num=7, stock=3143, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=945906386, sale=1417, score_num=293, stock=14663, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=804124918, sale=11, score_num=12, stock=965, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=71284154, sale=38, score_num=293, stock=135, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=279535059, sale=10, score_num=21, stock=20, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=839224691, sale=41, score_num=28, stock=6403, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=787053034, sale=35, score_num=43, stock=4872, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=828045191, sale=12, score_num=16, stock=79, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=185300283, sale=10, score_num=88, stock=154, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=979964168, sale=125, score_num=2, stock=475, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=886234211, sale=16, score_num=11, stock=30, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=94390093, sale=88, score_num=260, stock=4214, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=376670460, sale=15, score_num=58, stock=447, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=879321643, sale=37, score_num=28, stock=13951, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=266160475, sale=20, score_num=26, stock=28, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=619082694, sale=149, score_num=19, stock=9782, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=485431784, sale=16, score_num=31, stock=155, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=765277899, sale=163, score_num=25, stock=12804, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=88443370, sale=37, score_num=333, stock=27, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=955538795, sale=14, score_num=5, stock=98, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=667956559, sale=32, score_num=20, stock=133, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=689006548, sale=17, score_num=41, stock=84, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=905385921, sale=10, score_num=3, stock=984, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=286147276, sale=10, score_num=37, stock=14, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=129019678, sale=11, score_num=35, stock=558, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=577738472, sale=293, score_num=147, stock=1702, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=272196890, sale=35, score_num=182, stock=292, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=443523171, sale=11, score_num=24, stock=1127, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=600864128, sale=12, score_num=19, stock=3, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=162266895, sale=22, score_num=302, stock=17, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=980087896, sale=11, score_num=9, stock=499, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=713619737, sale=17, score_num=16, stock=669, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=514897057, sale=14, score_num=23, stock=4950, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=966222019, sale=52, score_num=6, stock=198, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=786029644, sale=19, score_num=15, stock=1970, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=119278418, sale=16, score_num=3, stock=384, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=609606220, sale=10, score_num=10, stock=45, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=131936, sale=33, score_num=96, stock=1185, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=63224878, sale=12, score_num=117, stock=24, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=798467953, sale=19, score_num=9, stock=30, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=861445273, sale=64, score_num=85, stock=3935, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=129374006, sale=15, score_num=54, stock=21, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=701640323, sale=10, score_num=19, stock=454, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=804544282, sale=21, score_num=3, stock=12, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=228056188, sale=180, score_num=824, stock=465, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=35909194, sale=23, score_num=68, stock=217, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=882613712, sale=476, score_num=192, stock=310, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=311911909, sale=14, score_num=71, stock=11, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=455572799, sale=22, score_num=31, stock=53, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=587391700, sale=45, score_num=49, stock=835, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=644110331, sale=57, score_num=23, stock=1318, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=153305792, sale=11, score_num=121, stock=57, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=302387923, sale=13, score_num=38, stock=1269, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=190340956, sale=13, score_num=129, stock=1248, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=843522244, sale=65, score_num=29, stock=4106, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=94997613, sale=105, score_num=1072, stock=1056, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=96145441, sale=25, score_num=273, stock=3873, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=426069035, sale=39, score_num=83, stock=1721, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=964654569, sale=14, score_num=2, stock=86, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=668232481, sale=43, score_num=9, stock=30, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=389859175, sale=54, score_num=108, stock=94, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=615295180, sale=12, score_num=4, stock=3282, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=209771795, sale=31, score_num=46, stock=4343, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=742616624, sale=18, score_num=46, stock=598, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=44674476, sale=39, score_num=301, stock=38, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=681912209, sale=1288, score_num=470, stock=903, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=957605802, sale=14, score_num=3, stock=17968, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=810482635, sale=13, score_num=17, stock=6, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=936445244, sale=10, score_num=0, stock=97, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=824376830, sale=18, score_num=22, stock=1959, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=350783544, sale=11, score_num=13, stock=46, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=110247034, sale=42, score_num=72, stock=69, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=465601515, sale=31, score_num=360, stock=856, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=756351593, sale=79, score_num=226, stock=565, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=859664151, sale=12, score_num=12, stock=5975, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=712102164, sale=16, score_num=15, stock=1971, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=315796591, sale=12, score_num=44, stock=278, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=385730863, sale=340, score_num=134, stock=43455, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=648465085, sale=19, score_num=25, stock=59, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=16537972, sale=63, score_num=310, stock=277, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=946295001, sale=11, score_num=11, stock=155, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=11996066, sale=12, score_num=175, stock=162, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=2885334, sale=199, score_num=2323, stock=133926, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=77038455, sale=29, score_num=54, stock=302, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=696198587, sale=56, score_num=21, stock=3912, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=16679441, sale=174, score_num=1071, stock=3910, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=290469209, sale=61, score_num=55, stock=170, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=811642900, sale=20, score_num=15, stock=14, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=49741151, sale=19, score_num=239, stock=2331, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=871220131, sale=16, score_num=10, stock=2669, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=879779154, sale=25, score_num=16, stock=3952, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=59814787, sale=13, score_num=92, stock=3788, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=120200125, sale=12, score_num=95, stock=747, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=185219709, sale=18, score_num=74, stock=537, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=346039791, sale=14, score_num=31, stock=17, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=758597112, sale=27, score_num=66, stock=496, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=1006426309, sale=11, score_num=1, stock=199, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=813958161, sale=13, score_num=18, stock=81, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=395800059, sale=16, score_num=64, stock=385, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=152563332, sale=37, score_num=65, stock=54, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=903397092, sale=27, score_num=14, stock=972, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=946661884, sale=78, score_num=48, stock=15, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=1001985433, sale=11, score_num=1, stock=1989, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=648681385, sale=48, score_num=81, stock=30, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=342483712, sale=15, score_num=44, stock=416, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=672632897, sale=23, score_num=121, stock=1863, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=938713180, sale=67, score_num=58, stock=69923, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=12182514, sale=19, score_num=164, stock=5999713, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=699965887, sale=10, score_num=19, stock=915, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=290757472, sale=14, score_num=66, stock=729, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=587370422, sale=23, score_num=21, stock=135, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=156993780, sale=21, score_num=141, stock=515, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=391450771, sale=10, score_num=70, stock=23, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=279334470, sale=15, score_num=25, stock=10941, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=181098568, sale=13, score_num=102, stock=1627, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=439669962, sale=13, score_num=12, stock=70, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=508335440, sale=21, score_num=100, stock=107, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=460803817, sale=20, score_num=155, stock=19888, update_time=datetime.date(2018, 4, 1)),
#  Row(item_id=639527120, sale=15, score_num=32, stock=221, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=820229615, sale=149, score_num=178, stock=214, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=502308151, sale=15, score_num=4, stock=85, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=414052938, sale=13, score_num=13, stock=1056, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=187677658, sale=13, score_num=65, stock=10, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=756949290, sale=36, score_num=29, stock=175, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=953929837, sale=17, score_num=4, stock=78, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=573776022, sale=14, score_num=44, stock=37, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=808155730, sale=18, score_num=27, stock=5966, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=17299729, sale=17, score_num=397, stock=643, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=738973235, sale=12, score_num=1, stock=28, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=847128910, sale=16, score_num=20, stock=366, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=787635119, sale=18, score_num=19, stock=3, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=117049381, sale=105, score_num=831, stock=9755, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=483700965, sale=38, score_num=65, stock=106, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=661984905, sale=15, score_num=39, stock=94, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=698739027, sale=11, score_num=13, stock=962, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=203150234, sale=20, score_num=139, stock=380, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=76046174, sale=12, score_num=65, stock=1999957, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=967817751, sale=20, score_num=9, stock=1570, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=775138787, sale=18, score_num=12, stock=7947, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=518380404, sale=42, score_num=99, stock=978, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=635522401, sale=77, score_num=114, stock=979, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=411370236, sale=14, score_num=7, stock=540, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=796084089, sale=15, score_num=23, stock=7, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=610943238, sale=17, score_num=61, stock=1374, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=699959294, sale=17, score_num=43, stock=15, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=885167620, sale=29, score_num=14, stock=6677, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=979164934, sale=22, score_num=17, stock=1678, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=1006422508, sale=160, score_num=2, stock=15, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=836498137, sale=134, score_num=117, stock=378, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=304797803, sale=48, score_num=174, stock=1955, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=640233094, sale=56, score_num=53, stock=1369, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=879665465, sale=12, score_num=8, stock=9, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=505411167, sale=162, score_num=226, stock=19506, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=302505424, sale=26, score_num=16, stock=7906, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=738917191, sale=15, score_num=5, stock=20, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=323718626, sale=15, score_num=42, stock=3102, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=117480439, sale=10, score_num=24, stock=101, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=322860814, sale=13, score_num=90, stock=1191, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=707728110, sale=16, score_num=28, stock=1932, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=751031445, sale=11, score_num=4, stock=10, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=76559179, sale=63, score_num=125, stock=185586, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=484387126, sale=41, score_num=67, stock=60, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=79633960, sale=13, score_num=296, stock=9954, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=789849736, sale=10, score_num=9, stock=6, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=19785647, sale=34, score_num=64, stock=116, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=4961313, sale=15, score_num=164, stock=25, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=420297477, sale=20, score_num=107, stock=733, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=34204709, sale=84, score_num=814, stock=6, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=320829658, sale=29, score_num=57, stock=471, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=987504113, sale=12, score_num=5, stock=89, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=115024262, sale=16, score_num=81, stock=174, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=174416206, sale=46, score_num=153, stock=866, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=807361833, sale=28, score_num=35, stock=14, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=847853168, sale=11, score_num=7, stock=8, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=22955838, sale=25, score_num=14, stock=1085, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=912803998, sale=12, score_num=9, stock=62, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=394613658, sale=19, score_num=12, stock=1679, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=17987566, sale=22, score_num=652, stock=222, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=852546230, sale=150, score_num=4, stock=675, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=840333277, sale=222, score_num=218, stock=927, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=893342502, sale=10, score_num=0, stock=20, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=781410805, sale=11, score_num=19, stock=52, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=309722554, sale=19, score_num=56, stock=3825, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=371011139, sale=34, score_num=363, stock=16, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=739376123, sale=106, score_num=170, stock=806, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=92127967, sale=51, score_num=123, stock=10, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=687736737, sale=13, score_num=48, stock=495, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=493280152, sale=29, score_num=15, stock=8926, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=28633624, sale=13, score_num=22, stock=162, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=466217802, sale=11, score_num=15, stock=966, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=121229706, sale=92, score_num=1631, stock=11945, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=313183068, sale=456, score_num=1048, stock=4584, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=793727083, sale=17, score_num=12, stock=0, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=97472795, sale=20, score_num=175, stock=6, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=84161926, sale=27, score_num=166, stock=49, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=995655468, sale=65, score_num=8, stock=9939, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=734505294, sale=10, score_num=9, stock=474, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=889339362, sale=17, score_num=15, stock=2674, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=282428022, sale=15, score_num=104, stock=1083, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=953237697, sale=12, score_num=5, stock=290, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=609606220, sale=11, score_num=10, stock=44, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=748890247, sale=15, score_num=50, stock=44, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=689372846, sale=46, score_num=77, stock=12, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=991437230, sale=547, score_num=24, stock=16, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=267909387, sale=10, score_num=6, stock=190, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=168285769, sale=125, score_num=652, stock=9975, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=603277580, sale=12, score_num=28, stock=58, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=225620966, sale=435, score_num=4407, stock=43215, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=438503383, sale=24, score_num=104, stock=8836, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=673707823, sale=12, score_num=12, stock=1942, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=135072182, sale=13, score_num=35, stock=2904, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=184802850, sale=11, score_num=151, stock=25, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=348590705, sale=59, score_num=167, stock=99, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=641872580, sale=13, score_num=44, stock=36, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=745041279, sale=104, score_num=52, stock=17855, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=234351648, sale=198, score_num=5886, stock=3011, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=823513977, sale=10, score_num=6, stock=378, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=903151833, sale=23, score_num=18, stock=13, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=511798764, sale=61, score_num=84, stock=450, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=300197803, sale=10, score_num=11, stock=19, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=402903277, sale=12, score_num=25, stock=38, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=124809202, sale=15, score_num=23, stock=550, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=217640085, sale=12, score_num=218, stock=5777, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=674237847, sale=10, score_num=16, stock=156, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=251331776, sale=17, score_num=138, stock=26, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=241151773, sale=10, score_num=57, stock=11, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=36076924, sale=107, score_num=526, stock=996955, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=927187106, sale=34, score_num=15, stock=90, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=15682889, sale=59, score_num=726, stock=17, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=72651287, sale=16, score_num=109, stock=803, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=641202904, sale=55, score_num=50, stock=1139, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=839818218, sale=13, score_num=8, stock=30, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=751654779, sale=16, score_num=23, stock=840, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=830081176, sale=19, score_num=10, stock=7, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=385686923, sale=390, score_num=2105, stock=4299, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=381174208, sale=15, score_num=74, stock=92, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=31661007, sale=11, score_num=49, stock=53, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=398179933, sale=98, score_num=509, stock=160, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=87741604, sale=10, score_num=17, stock=362, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=160490916, sale=54, score_num=268, stock=4062, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=733996962, sale=15, score_num=19, stock=60, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=390242181, sale=21, score_num=34, stock=74, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=132559792, sale=10, score_num=236, stock=43, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=380496412, sale=20, score_num=39, stock=923, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=875582191, sale=10, score_num=17, stock=31, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=16017930, sale=28, score_num=99, stock=196, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=40700434, sale=23, score_num=57, stock=4938, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=118874771, sale=54, score_num=513, stock=74, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=761955976, sale=10, score_num=38, stock=66, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=676486769, sale=16, score_num=14, stock=209, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=138739617, sale=33, score_num=390, stock=121, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=68529108, sale=145, score_num=651, stock=144, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=704121792, sale=26, score_num=8, stock=318, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=859716864, sale=11, score_num=6, stock=1965, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=190781384, sale=16, score_num=113, stock=3879, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=227491493, sale=165, score_num=267, stock=1234, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=1029416567, sale=12, score_num=1, stock=9987, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=63367913, sale=18, score_num=180, stock=2738, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=804124918, sale=11, score_num=13, stock=965, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=839803151, sale=109, score_num=29, stock=10, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=29489619, sale=39, score_num=98, stock=252, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=908291767, sale=50, score_num=53, stock=177, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=102360756, sale=17, score_num=126, stock=1164, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=224359025, sale=14, score_num=37, stock=91, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=49829205, sale=20, score_num=23, stock=223, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=990729268, sale=91, score_num=20, stock=32, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=438086343, sale=22, score_num=15, stock=15, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=508469714, sale=113, score_num=410, stock=6107, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=883752327, sale=16, score_num=4, stock=1978, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=660690723, sale=17, score_num=59, stock=9, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=264273583, sale=51, score_num=141, stock=783, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=13003544, sale=393, score_num=1187, stock=923, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=126173374, sale=12, score_num=77, stock=124, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=908256875, sale=18, score_num=11, stock=66, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=323372637, sale=13, score_num=109, stock=249, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=720824885, sale=11, score_num=5, stock=579, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=324094110, sale=103, score_num=205, stock=327, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=846131439, sale=10, score_num=16, stock=17, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=521108661, sale=30, score_num=9, stock=264, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=3909525, sale=11, score_num=68, stock=34, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=994420146, sale=21, score_num=4, stock=979, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=810509390, sale=101, score_num=140, stock=264, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=945906386, sale=1388, score_num=315, stock=14647, update_time=datetime.date(2018, 4, 2)),
#  Row(item_id=1008073747, sale=10, score_num=3, stock=990, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=631381479, sale=128, score_num=88, stock=2517, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=933525777, sale=40, score_num=39, stock=26, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=470877813, sale=26, score_num=22, stock=421, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=9222307, sale=27, score_num=185, stock=5814, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=24233465, sale=13, score_num=46, stock=335, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=95007691, sale=45, score_num=781, stock=46, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=885663031, sale=20, score_num=37, stock=168, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=246094486, sale=41, score_num=249, stock=1288, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=89941492, sale=41, score_num=131, stock=8995, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=382587222, sale=85, score_num=67, stock=244, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=567595860, sale=11, score_num=10, stock=6973, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=810017783, sale=19, score_num=23, stock=27, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=361587568, sale=24, score_num=56, stock=9886, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=979194941, sale=10, score_num=0, stock=90, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=906135759, sale=19, score_num=9, stock=285, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=146065155, sale=15, score_num=66, stock=69933, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=221412070, sale=169, score_num=183, stock=995, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=13122784, sale=16, score_num=87, stock=240, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=976238717, sale=111, score_num=11, stock=774, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=829365530, sale=34, score_num=18, stock=97, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=504786639, sale=13, score_num=34, stock=46, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=531815426, sale=15, score_num=14, stock=10920, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=2042493, sale=10, score_num=584, stock=106, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=64111688, sale=57, score_num=209, stock=28, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=704400455, sale=240, score_num=17, stock=469, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=911370274, sale=10, score_num=9, stock=0, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=12093537, sale=15, score_num=67, stock=41, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=990729268, sale=95, score_num=20, stock=31, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=737216846, sale=29, score_num=7, stock=76, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=5510921, sale=22, score_num=248, stock=530, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=9820034, sale=33, score_num=283, stock=419, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=692497938, sale=10, score_num=22, stock=23, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=956128551, sale=14, score_num=9, stock=29, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=302219210, sale=180, score_num=150, stock=3023, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=102103929, sale=51, score_num=99, stock=1870, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=512869198, sale=11, score_num=34, stock=2936, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=685213326, sale=148, score_num=213, stock=30, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=319088008, sale=10, score_num=40, stock=67, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=18457451, sale=10, score_num=20, stock=66, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=822741692, sale=11, score_num=9, stock=5978, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=938396382, sale=11, score_num=16, stock=60, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=170306923, sale=30, score_num=202, stock=701, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=1023681631, sale=10, score_num=0, stock=7990, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=432123519, sale=48, score_num=191, stock=1110, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=787053836, sale=41, score_num=31, stock=3917, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=184231589, sale=13, score_num=65, stock=26, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=949468278, sale=18, score_num=5, stock=3, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=479227250, sale=18, score_num=107, stock=2052, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=62449791, sale=14, score_num=295, stock=35, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=757871720, sale=15, score_num=19, stock=4, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=1001985433, sale=13, score_num=1, stock=1987, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=670661142, sale=45, score_num=91, stock=69, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=524205932, sale=183, score_num=252, stock=1845, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=497479197, sale=254, score_num=165, stock=231, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=376670460, sale=16, score_num=58, stock=447, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=985039942, sale=12, score_num=5, stock=6, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=893461687, sale=19, score_num=19, stock=312, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=236047863, sale=13, score_num=15, stock=32, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=20941485, sale=13, score_num=97, stock=113, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=651549445, sale=10, score_num=8, stock=973, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=213929437, sale=25, score_num=14, stock=100, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=589244842, sale=31, score_num=32, stock=4652, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=915563491, sale=225, score_num=144, stock=672, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=888905660, sale=37, score_num=32, stock=851, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=970247829, sale=10, score_num=5, stock=89, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=308970826, sale=39, score_num=110, stock=309, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=967830383, sale=179, score_num=67, stock=310, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=401188916, sale=23, score_num=10, stock=41, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=387553376, sale=19, score_num=109, stock=202, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=232287843, sale=13, score_num=128, stock=54, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=722605259, sale=14, score_num=23, stock=70, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=790991061, sale=48, score_num=64, stock=157, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=668748454, sale=45, score_num=56, stock=100, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=235514953, sale=14, score_num=70, stock=12174, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=206378885, sale=23, score_num=102, stock=1595, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=169477193, sale=13, score_num=151, stock=38, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=134962144, sale=83, score_num=312, stock=165, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=343406034, sale=80, score_num=49, stock=250, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=203164173, sale=42, score_num=142, stock=627, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=416882967, sale=10, score_num=35, stock=997, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=254213009, sale=35, score_num=99, stock=474, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=848586618, sale=19, score_num=16, stock=767, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=846489819, sale=27, score_num=10, stock=211, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=55657389, sale=202, score_num=2440, stock=284271, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=627753183, sale=58, score_num=73, stock=813, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=26626685, sale=16, score_num=223, stock=451, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=874402519, sale=11, score_num=4, stock=1789, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=840965056, sale=10, score_num=8, stock=180, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=29793511, sale=80, score_num=12, stock=69, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=824376830, sale=18, score_num=22, stock=1959, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=982564762, sale=14, score_num=3, stock=32986, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=785258207, sale=20, score_num=27, stock=276, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=286085454, sale=31, score_num=1015, stock=815, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=953142101, sale=44, score_num=9, stock=3956, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=684103312, sale=206, score_num=83, stock=7069, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=796362547, sale=11, score_num=23, stock=46, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=168079951, sale=83, score_num=606, stock=7238, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=80270877, sale=10, score_num=55, stock=74, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=268711002, sale=14, score_num=44, stock=1176, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=583034720, sale=13, score_num=4, stock=30, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=506284061, sale=11, score_num=78, stock=5361, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=1018266042, sale=53, score_num=0, stock=16930, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=148269720, sale=11, score_num=77, stock=881, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=474777707, sale=11, score_num=30, stock=6, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=397093677, sale=21, score_num=51, stock=1283, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=868667797, sale=22, score_num=14, stock=462, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=1002145734, sale=35, score_num=3, stock=1460, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=628371928, sale=16, score_num=21, stock=6, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=914204052, sale=55, score_num=75, stock=282, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=889423840, sale=30, score_num=10, stock=20, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=897623193, sale=17, score_num=19, stock=2162, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=807542362, sale=27, score_num=12, stock=1012, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=972812823, sale=12, score_num=1, stock=10, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=798795782, sale=14, score_num=19, stock=1920, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=42180085, sale=38, score_num=135, stock=316, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=258757466, sale=27, score_num=87, stock=133, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=173188114, sale=60, score_num=1185, stock=166, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=1016039919, sale=17, score_num=1, stock=982, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=649952579, sale=55, score_num=154, stock=122, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=318088638, sale=18, score_num=137, stock=12432, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=708248692, sale=38, score_num=56, stock=296, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=812305048, sale=180, score_num=267, stock=2260, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=650258361, sale=13, score_num=21, stock=119, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=175192480, sale=237, score_num=153, stock=421, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=977395209, sale=51, score_num=4, stock=948, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=787890557, sale=13, score_num=6, stock=593, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=879321643, sale=38, score_num=28, stock=13949, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=967317825, sale=12, score_num=7, stock=150, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=30793553, sale=20, score_num=55, stock=5934, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=885332656, sale=10, score_num=8, stock=384, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=29714041, sale=19, score_num=1163, stock=94, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=888637403, sale=186, score_num=115, stock=1720, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=18269565, sale=23, score_num=51, stock=266610, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=141392394, sale=82, score_num=387, stock=801, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=882487235, sale=144, score_num=108, stock=877, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=90794835, sale=113, score_num=238, stock=5573, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=800304276, sale=23, score_num=22, stock=112, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=679888415, sale=33, score_num=56, stock=75, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=112814845, sale=107, score_num=154, stock=847, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=12973049, sale=66, score_num=870, stock=2810, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=167624632, sale=10, score_num=13, stock=959, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=304410788, sale=48, score_num=204, stock=37, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=848262807, sale=13, score_num=5, stock=25, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=1003571856, sale=16, score_num=2, stock=7984, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=54622066, sale=35, score_num=24, stock=21, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=870354171, sale=13, score_num=9, stock=211, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=267714326, sale=23, score_num=63, stock=268, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=232210388, sale=44, score_num=54, stock=932, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=1003421181, sale=52, score_num=27, stock=23, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=1009845778, sale=16, score_num=0, stock=3644, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=822976987, sale=19, score_num=16, stock=174, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=391843645, sale=66, score_num=222, stock=21209, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=729994595, sale=212, score_num=234, stock=392, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=176392564, sale=10, score_num=0, stock=150, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=415109467, sale=12, score_num=26, stock=5950, update_time=datetime.date(2018, 4, 3)),
#  Row(item_id=311083359, sale=12, score_num=58, stock=145, update_time=datetime.date(2018, 4, 3)),
# ...
#  Row(item_id=691006566, sale=18, score_num=49, stock=3320, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=464738817, sale=15, score_num=69, stock=146, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=12973049, sale=62, score_num=870, stock=2809, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=154955685, sale=30, score_num=134, stock=255, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=29793511, sale=66, score_num=12, stock=38, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=94997613, sale=108, score_num=1075, stock=1049, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=298577396, sale=58, score_num=265, stock=105, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=746974028, sale=319, score_num=408, stock=398, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=1019025448, sale=130, score_num=0, stock=1370, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=584746071, sale=16, score_num=4, stock=27, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=908770478, sale=17, score_num=16, stock=43, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=75734901, sale=14, score_num=100, stock=172, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=508468757, sale=289, score_num=459, stock=4986, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=915563491, sale=230, score_num=147, stock=665, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=737216846, sale=22, score_num=7, stock=76, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=995454087, sale=19, score_num=7, stock=54, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=57115348, sale=104, score_num=243, stock=6902, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=318428534, sale=51, score_num=105, stock=2367, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=733928459, sale=46, score_num=43, stock=110, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=635583295, sale=13, score_num=4, stock=1185, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=751102296, sale=11, score_num=3, stock=75, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=882506324, sale=96, score_num=128, stock=514, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=281841342, sale=10, score_num=30, stock=91, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=849743351, sale=18, score_num=15, stock=668, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=497479197, sale=430, score_num=168, stock=302, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=879321643, sale=37, score_num=28, stock=13949, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=509305018, sale=17, score_num=29, stock=78, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=685213326, sale=148, score_num=214, stock=26, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=232210388, sale=44, score_num=54, stock=932, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=977395209, sale=51, score_num=6, stock=945, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=967830383, sale=268, score_num=67, stock=83, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=175192480, sale=247, score_num=153, stock=416, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=247319850, sale=121, score_num=1035, stock=3940, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=98602011, sale=39, score_num=499, stock=493, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=236047863, sale=13, score_num=15, stock=32, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=104157758, sale=12, score_num=91, stock=2955, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=985039942, sale=12, score_num=5, stock=6, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=862273485, sale=46, score_num=88, stock=107, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=203164173, sale=43, score_num=144, stock=626, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=22570901, sale=10, score_num=31, stock=562, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=201862263, sale=14, score_num=102, stock=3964, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=569189940, sale=806, score_num=11, stock=855, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=627753183, sale=54, score_num=73, stock=813, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=437419457, sale=55, score_num=121, stock=874, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=673595751, sale=98, score_num=195, stock=334, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=137167584, sale=11, score_num=9, stock=131, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=64111688, sale=56, score_num=209, stock=31, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=474777707, sale=12, score_num=31, stock=2, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=994742675, sale=11, score_num=1, stock=1818, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=268711002, sale=15, score_num=44, stock=1175, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=312917485, sale=25, score_num=97, stock=66, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=889423840, sale=32, score_num=10, stock=18, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=709468153, sale=18, score_num=33, stock=316, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=30368229, sale=15, score_num=157, stock=10465, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=812305048, sale=180, score_num=267, stock=2258, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=886876961, sale=54, score_num=18, stock=2421, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=107917298, sale=14, score_num=107, stock=17, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=467241708, sale=10, score_num=21, stock=76, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=28633624, sale=11, score_num=22, stock=162, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=773535361, sale=14, score_num=12, stock=62, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=1001985433, sale=16, score_num=2, stock=1984, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=589244842, sale=32, score_num=32, stock=4651, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=454557492, sale=17, score_num=21, stock=663, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=843174192, sale=18, score_num=26, stock=10, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=619082694, sale=146, score_num=19, stock=9782, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=770540300, sale=54, score_num=31, stock=9, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=860811257, sale=12, score_num=6, stock=5011, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=557538607, sale=29, score_num=168, stock=1284, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=965530028, sale=27, score_num=5, stock=587, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=168079951, sale=83, score_num=606, stock=7238, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=30793553, sale=19, score_num=55, stock=5933, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=450244962, sale=30, score_num=87, stock=431, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=953142101, sale=44, score_num=9, stock=3956, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=670661142, sale=45, score_num=91, stock=66, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=29714041, sale=19, score_num=1163, stock=94, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=270778211, sale=34, score_num=156, stock=66, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=470877813, sale=23, score_num=23, stock=421, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=979897565, sale=23, score_num=5, stock=30653, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=85844137, sale=933, score_num=4185, stock=8306, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=783537128, sale=19, score_num=8, stock=99, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=136996363, sale=22, score_num=57, stock=6, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=797538459, sale=10, score_num=3, stock=589, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=468902695, sale=35, score_num=48, stock=19, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=71284154, sale=31, score_num=293, stock=133, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=57388229, sale=35, score_num=161, stock=639, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=798795782, sale=14, score_num=19, stock=1920, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=479227250, sale=23, score_num=107, stock=2047, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=17421229, sale=203, score_num=644, stock=9903, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=102103929, sale=51, score_num=99, stock=1870, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=319847959, sale=42, score_num=259, stock=42, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=20941485, sale=12, score_num=97, stock=113, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=529472722, sale=10, score_num=22, stock=1474, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=760602400, sale=58, score_num=7, stock=2911, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=26626685, sale=16, score_num=223, stock=451, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=824376830, sale=17, score_num=22, stock=1959, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=984885198, sale=24, score_num=5, stock=776, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=65375872, sale=11, score_num=67, stock=417, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=185763769, sale=25, score_num=169, stock=145, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=796877281, sale=47, score_num=56, stock=403, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=679871068, sale=38, score_num=20, stock=1399, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=990729268, sale=97, score_num=21, stock=27, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=319234323, sale=14, score_num=137, stock=11, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=96100162, sale=52, score_num=288, stock=59, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=73605756, sale=13, score_num=84, stock=554, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=952035298, sale=100, score_num=5, stock=388, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=863314682, sale=49, score_num=65, stock=2915, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=1002549620, sale=20, score_num=1, stock=6, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=311087366, sale=22, score_num=35, stock=107, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=221412070, sale=170, score_num=189, stock=991, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=27665495, sale=11, score_num=148, stock=141, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=213929437, sale=25, score_num=14, stock=99, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=419669095, sale=48, score_num=287, stock=6140, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=722605259, sale=14, score_num=23, stock=70, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=62449791, sale=14, score_num=295, stock=33, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=865553219, sale=10, score_num=14, stock=273, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=723169467, sale=20, score_num=9, stock=39, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=674272701, sale=123, score_num=266, stock=278, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=95166580, sale=27, score_num=366, stock=465, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=206378885, sale=22, score_num=102, stock=1595, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=9150531, sale=33, score_num=72, stock=1625, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=945836819, sale=14, score_num=4, stock=7989, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=141377842, sale=46, score_num=475, stock=717, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=137346666, sale=21, score_num=340, stock=2074, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=810509390, sale=111, score_num=144, stock=254, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=815268984, sale=33, score_num=11, stock=99, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=843522244, sale=82, score_num=30, stock=4093, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=571960396, sale=18, score_num=10, stock=30, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=938396382, sale=11, score_num=16, stock=60, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=66304201, sale=12, score_num=66, stock=16, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=903151833, sale=23, score_num=19, stock=11, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=1002145734, sale=36, score_num=3, stock=1459, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=2853660, sale=30, score_num=247, stock=9002, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=897623193, sale=17, score_num=19, stock=2162, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=112064815, sale=29, score_num=90, stock=7386, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=691071553, sale=356, score_num=701, stock=18557, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=962802412, sale=37, score_num=6, stock=962, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=350982056, sale=10, score_num=28, stock=125, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=314882934, sale=70, score_num=140, stock=10688, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=887481010, sale=43, score_num=18, stock=99928, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=265236096, sale=267, score_num=571, stock=5595, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=757871720, sale=14, score_num=19, stock=4, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=83176842, sale=11, score_num=206, stock=499, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=759335298, sale=37, score_num=34, stock=27, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=927187106, sale=32, score_num=15, stock=88, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=987160994, sale=25, score_num=8, stock=189, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=168779340, sale=89, score_num=291, stock=101, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=277021489, sale=13, score_num=87, stock=62, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=1001844810, sale=10, score_num=3, stock=17972, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=302500433, sale=28, score_num=201, stock=10013, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=785258207, sale=22, score_num=27, stock=276, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=169477193, sale=11, score_num=151, stock=38, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=938369836, sale=98, score_num=30, stock=130, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=697438856, sale=12, score_num=9, stock=85, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=888637403, sale=167, score_num=115, stock=1715, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=304410788, sale=45, score_num=205, stock=37, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=203276237, sale=13, score_num=36, stock=421, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=859400851, sale=19, score_num=10, stock=772, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=251331776, sale=16, score_num=138, stock=26, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=40721859, sale=10, score_num=31, stock=7913, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=5510921, sale=22, score_num=248, stock=530, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=167624632, sale=10, score_num=13, stock=959, update_time=datetime.date(2018, 4, 4)),
#  Row(item_id=506284061, sale=11, score_num=78, stock=5361, update_time=datetime.date(2018, 4, 4)),
#  ...]

# %% [markdown]
# ### 實際應用

# %%
stockSaleRateRDD = testDataRDD.map(countSaleRateByStock)
stockSaleRateRDD.count()
# Out:
# 70408

# %%
stockSaleRateRDD.takeOrdered(10, key=lambda x: -x[-1])
# Out:
# [(945906386,
#   '手機周邊配件',
#   '新款四代吃雞神器_附發票最新款卡扣式_快捷射擊按鍵神器_手機搖桿_荒野行動_絕地求生_射擊按鍵AB920',
#   16,
#   1,
#   16.0),
#  (85844137,
#   '手機周邊配件',
#   '現貨新款升級_線控_藍芽_美顏_補光燈_A6_自拍神器自拍棒_自拍桿_補光_手機_自拍_CYKE_ADYSS_藍牙',
#   11,
#   1,
#   11.0),
#  (175192480,
#   '手機周邊配件',
#   '現貨_多款_卡通造型_掛繩_可拆式_手機掛繩_迪士尼_小新_史迪奇_無臉男_宮崎駿_米妮_山茶花',
#   5,
#   1,
#   5.0),
#  (832737770, '手機周邊配件', '現貨預購_KAKAO_FRIENDS_新款可伸縮氣囊多功能手機支架_通用款_', 3, 1, 3.0),
#  (888637403,
#   '耳機喇叭',
#   'MToy總代理台灣公司貨_防掉防汗水_IPX67運動耳機_無線耳機_重低音_磁吸_藍牙耳機_藍芽耳機',
#   11,
#   2,
#   3.0),
#  (524474627,
#   'iPhone保護殼',
#   'iPhone轉聲_空壓殼_四角防摔_前置轉聲__iPhone7_iPhone8_Plus_i7_i8_iX',
#   6,
#   2,
#   3.0),
#  (474042478,
#   'Android保護殼',
#   'BlACK英文_磨砂手機殼S8S8plusJ7A7J5_2016版A5红米NOTE4红米NOTE3小米6',
#   3,
#   1,
#   3.0),
#  (457334233, 'iPhone充電傳輸', '大量現貨蘋果iphone線套保護套_創意線套_數據線保護器_i線套', 10, 4, 2.5),
#  (956128551,
#   '耳機喇叭',
#   '現貨供貨QCY_T1_PRO_觸碰藍芽耳機_磁吸藍牙耳機_運動藍芽耳機_音樂藍牙耳機_藍芽耳機_Q29_2代',
#   5,
#   2,
#   2.5),
#  (192078474,
#   'Android保護貼',
#   '滿版全膠_HTC_U_UltraU11U11Eyes全版鋼化玻璃保護貼防碎手機螢幕防爆玻璃貼',
#   5,
#   2,
#   2.5)]

# %% [markdown]
# # 做成pandas Dataframe

# %%
stockSaleRateDF = spark.createDataFrame(stockSaleRateRDD.takeOrdered(stockSaleRateRDD.count(), key=lambda x: -x[-1]), ["item_id", "category_name", "name", "庫存變化", "日期差", "銷售頻率"])
stockSaleRateDF.count()
# Out:
# 70408

# %%
stockSaleRatePDDF = stockSaleRateDF.toPandas()
stockSaleRatePDDF.index.name="id"
today = datetime.date.today()

stockSaleRatePDDF.to_csv("stockSaleRate_Output/"+str(today)+"_SaleRateChart.csv", encoding='utf-8')
# Out:
# ----------------------------------------
# Exception happened during processing of request from ('127.0.0.1', 58840)
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.6/socketserver.py", line 317, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/opt/conda/lib/python3.6/socketserver.py", line 348, in process_request
#     self.finish_request(request, client_address)
#   File "/opt/conda/lib/python3.6/socketserver.py", line 361, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/opt/conda/lib/python3.6/socketserver.py", line 696, in __init__
#     self.handle()
#   File "/usr/local/spark/python/pyspark/accumulators.py", line 235, in handle
#     num_updates = read_int(self.rfile)
#   File "/usr/local/spark/python/pyspark/serializers.py", line 577, in read_int
#     raise EOFError
# EOFError
# ----------------------------------------
