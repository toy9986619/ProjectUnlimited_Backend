# %%
import mysql.connector as mariadb
import pandas as pd

# %%
pd.read_csv('HotMonthSale_output/2018-04-22_itemHotMonthSaleChart.csv')
# Out:
#         id     item_id category_name  最大月銷量  最小月銷量  熱銷程度 update_time
# 0        0   225620966          耳機喇叭    435    435  超級熱銷  2018-04-22
# 1        1    13003544          耳機喇叭    393    393  超級熱銷  2018-04-22
# 2        2   746974028          耳機喇叭    326    319  超級熱銷  2018-04-22
# 3        3    15349092          耳機喇叭    227    227  超級熱銷  2018-04-22
# 4        4   840333277          耳機喇叭    222    222  超級熱銷  2018-04-22
# 5        5   526162583          耳機喇叭    199    198  超級熱銷  2018-04-22
# 6        6   518148225          耳機喇叭    195    195  超級熱銷  2018-04-22
# 7        7   888637403          耳機喇叭    186    155  超級熱銷  2018-04-22
# 8        8    16679441          耳機喇叭    174    174  超級熱銷  2018-04-22
# 9        9     5962349          耳機喇叭    165    165  超級熱銷  2018-04-22
# 10      10   820229615          耳機喇叭    149    149  超級熱銷  2018-04-22
# 11      11   117811570          耳機喇叭    137    134  超級熱銷  2018-04-22
# 12      12    11225630          耳機喇叭    134    134  超級熱銷  2018-04-22
# ...
